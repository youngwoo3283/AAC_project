# %%
import pandas as pd
import numpy as np

# %%
from tool import get_text,get_image,make_df,extract_consonant,is_noun,extract_verb

# %%
df = pd.read_csv('aac.csv')

# %%
url = "http://symbol.ksaac.or.kr/searchsymbols/searchbycategory?cago=3"

li_food_text = get_text(url)
li_food_image = get_image(url)

df_food = make_df(li_food_text,li_food_image)

df_food['카테고리_주제'] = '음식'
df_food['카테고리_품사'] = '0'

# %%
df_food.head()
# Out:
#      text                                              image
# 0  간장에찍어요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...
# 1     갈비탕  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...
# 2    고추잡채  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...
# 3  고추장넣어요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...
# 4  고추장주세요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...

# %%
df_food['카테고리_주제'] = '음식'

# %%
df_food['카테고리_품사'] = '0'

# %% [markdown]
# # 해당 토큰이 명사인지 판별하기
# - 2글자 이하는 먼저 다 명사로 치환하고 눈으로 아닌것만 바꿔줌
# - 3글자부터는 종성 분리를 통해서 명사만 추출하고 남은 것들도 다시 눈으로 확인 필요

# %%
from tqdm import tqdm

noun = list(map(lambda x : is_noun(x),df_food['text'].to_list()))

df_food['카테고리_주제'] = noun

# %%
df_food
# Out:
#         text                                              image 카테고리_주제  \
# 0     간장에찍어요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...       0
# 1        갈비탕  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...       0
# 2       고추잡채  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...       0
# 3     고추장넣어요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...       0
# 4     고추장주세요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...       0
# ...      ...                                                ...     ...
# 1070    프라이팬  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...       0
# 1071    프라이팬  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...       0
# 1072     하나더  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...       0
# 1073     하나더  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...       0
# 1074     정말요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...       0
#
#      카테고리_품사
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# ...

# %%
url = "http://symbol.ksaac.or.kr/searchsymbols/searchbycategory?cago=32"

li_food_text = get_text(url)
li_food_image = get_image(url)

df_food1 = make_df(li_food_text,li_food_image)

# %%
#df_food1

# %%
#음료 및 음식과 관

id = []
for i in range(df_food1.shape[0]):
    temp = df_food1.iloc[i,0]
    if temp[-1] =="요":
       id.append(i)

df_food1_id=df_food1.iloc[id] 
df_food1_id.drop(index =[12,13,56,77,82,83,84,85,80,99,100,101,102,114,124],inplace = True )
#df_food1_id
# Out:
# C:\Users\seo.jiyoung\AppData\Local\Temp\ipykernel_3080\1838262105.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_food1_id.drop(index =[12,13,56,77,82,83,84,85,80,99,100,101,102,114,124],inplace = True )

# %%
#밥 반찬

url = "http://symbol.ksaac.or.kr/searchsymbols/searchbycategory?cago=33"

df_food2_id = extract_verb(url)
df_food2_id.drop(index = [11,50,76,77,],inplace=True)

#df_food2_id

# %%
#과일 채소 곡식

url = "http://symbol.ksaac.or.kr/searchsymbols/searchbycategory?cago=34"

df_food3_id = extract_verb(url)
df_food3_id.drop(index = [50,51,67,68],inplace=True)

#df_food3_id

# %%
#해산물 고기

url = "http://symbol.ksaac.or.kr/searchsymbols/searchbycategory?cago=35"

df_food4_id = extract_verb(url)
df_food4_id.drop(index = [1,2],inplace=True)

#df_food4_id

# %%
#양념

url = "http://symbol.ksaac.or.kr/searchsymbols/searchbycategory?cago=36"

df_food5_id = extract_verb(url)
df_food5_id.drop(index = [30,59,60,65],inplace=True)

#df_food5_id

# %%
#간식

url = "http://symbol.ksaac.or.kr/searchsymbols/searchbycategory?cago=37"

df_food6_id = extract_verb(url)
df_food6_id.drop(index = [72,73,74,187,188,189],inplace=True)

#df_food6_id

# %%
#외식

url = "http://symbol.ksaac.or.kr/searchsymbols/searchbycategory?cago=38"

df_food7_id = extract_verb(url)
#df_food7_id.drop(index = [23,25,74,49,50,52,53,56,57,58,59,61,72,73,74,77,],inplace=True)

#df_food7_id

# %%
# 식기

url = "http://symbol.ksaac.or.kr/searchsymbols/searchbycategory?cago=39"

df_food8_id = extract_verb(url)
df_food8_id.drop(index = [15,16,17,18,19,20],inplace=True)
#df_food8_id

# %%
df_food = pd.read_csv('df_food.csv')

# %%
df_food['카테고리_세부분류'] = '0'

# %%
df_food[df_food['text'] =='감자깎이']
# Out:
#       text                                              image 카테고리_주제  \
# 1002  감자깎이  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사
#
#       카테고리_품사 카테고리_세부분류
# 1002        0         0

# %%
for i in range(0,1002):
    temp = df_food.iloc[i,0]
    df_food['카테고리_세부분류'] = '음식물'

# %%
df_food
# Out:
#         text                                              image 카테고리_주제  \
# 0     간장에찍어요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...       0
# 1        갈비탕  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사
# 2       고추잡채  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사
# 3     고추장넣어요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...       0
# 4     고추장주세요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...       0
# ...      ...                                                ...     ...
# 1070    프라이팬  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사
# 1071    프라이팬  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사
# 1072     하나더  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...       0
# 1073     하나더  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...       0
# 1074     정말요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...       0
#
#       카테고리_품사 카테고리_세부분류
# 0           0       음식물
# 1           0       음식물
# 2           0       음식물
# ...

# %%
df_food.rename(columns={'카테고리_주제':'카테고리_품사1'},inplace=True)

# %%
df_food.rename(columns={'카테고리_품사':'카테고리_주제',
                        '카테고리_품사1':'카테고리_품사'},inplace=True)

# %%
df_food['카테고리_주제'] = '음식'

# %%
df_food
# Out:
#         text                                              image 카테고리_품사  \
# 0     간장에찍어요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...       0
# 1        갈비탕  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사
# 2       고추잡채  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사
# 3     고추장넣어요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...       0
# 4     고추장주세요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...       0
# ...      ...                                                ...     ...
# 1070    프라이팬  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사
# 1071    프라이팬  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사
# 1072     하나더  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...       0
# 1073     하나더  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...       0
# 1074     정말요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...       0
#
#      카테고리_주제 카테고리_세부분류
# 0         음식       음식물
# 1         음식       음식물
# 2         음식       음식물
# ...

# %%
df_food_noun=df_food.query('(카테고리_품사 == "명사") and (카테고리_세부분류 == "음식물")')

# %%
df_food_noun = pd.read_csv('df_food_noun.csv')

# %%
df_food_noun
# Out:
#      text                                              image 카테고리_품사 카테고리_주제  \
# 0     갈비탕  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사      음식
# 1    고추잡채  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사      음식
# 2      과자  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사      음식
# 3      과자  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사      음식
# 4       국  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사      음식
# ..    ...                                                ...     ...     ...
# 761    포크  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사      음식
# 762    포크  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사      음식
# 763    포크  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사      음식
# 764  프라이팬  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사      음식
# 765  프라이팬  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사      음식
#
#     카테고리_세부분류
# 0         음식물
# ...

# %%
df_food1_id
# Out:
#        text                                              image
# 0     갈아주세요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...
# 1     갈아주세요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...
# 2     끓여주세요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...
# 6    더먹고싶어요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...
# 7    더먹고싶어요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...
# 14       따요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...
# 15       따요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...
# 16       따요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...
# 17     따주세요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...
# 22      떫어요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...
# 23      떫어요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...
# 26      마셔요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...
# 27      마셔요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...
# 28     마실래요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...
# ...

# %%
temp = df_food_noun[df_food_noun['카테고리_세부분류'] == '음식물']
temp
# Out:
#       text                                              image 카테고리_품사 카테고리_주제  \
# 0      갈비탕  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사      음식
# 1     고추잡채  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사      음식
# 2       과자  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사      음식
# 3       과자  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사      음식
# 4        국  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사      음식
# ..     ...                                                ...     ...     ...
# 712     한식  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사      음식
# 713  한정식-집  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사      음식
# 714   한정식집  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사      음식
# 715   한정식집  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사      음식
# 716   해물잡탕  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사      음식
#
#     카테고리_세부분류
# 0         음식물
# ...

# %%
temp.reset_index(drop = True,inplace=True)

# %%
#음식 관련 명사 데이터프레임
temp.head()
# Out:
#    text                                              image 카테고리_품사 카테고리_주제  \
# 0   갈비탕  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사      음식
# 1  고추잡채  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사      음식
# 2    과자  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사      음식
# 3    과자  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사      음식
# 4     국  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사      음식
#
#   카테고리_세부분류
# 0       음식물
# 1       음식물
# 2       음식물
# 3       음식물
# 4       음식물

# %%
df_food1_id
df_food1_id.shape[0]
# Out:
# 43

# %%
#문장을 만들고 사용된 토큰도 따로 저장하기

sentence = []
token = []

for i in range(temp.shape[0]):
    text = temp.iloc[i,0]
    for j in range(df_food3_id.shape[0]):
        
        try:
            text_s = df_food3_id.iloc[j,0]
            sentence.append(text+"을 "+ text_s)
            token.append([text,text_s])
        except:
            print(f'{i}와 {j}번쨰 인덱스에서 오류발생')

# %%
len(sentence)
# Out:
# 13186

# %%
sentence
# Out:
# ['갈비탕을 깎아요',
#  '갈비탕을 깎아요',
#  '갈비탕을 따요',
#  '갈비탕을 따요',
#  '갈비탕을 사요',
#  '갈비탕을 사요',
#  '갈비탕을 상해요',
#  '갈비탕을 상해요',
#  '갈비탕을 새콤해요',
#  '갈비탕을 새콤해요',
#  '갈비탕을 싱싱해요',
#  '갈비탕을 싸요',
#  '갈비탕을 싸요',
#  '갈비탕을 씻어요',
#  '갈비탕을 씻어요',
#  '갈비탕을 익어요',
#  '갈비탕을 익어요',
#  '갈비탕을 잘라주세요',
#  '갈비탕을 잘라주세요',
#  '고추잡채을 깎아요',
#  '고추잡채을 깎아요',
#  '고추잡채을 따요',
#  '고추잡채을 따요',
#  '고추잡채을 사요',
#  '고추잡채을 사요',
#  '고추잡채을 상해요',
#  '고추잡채을 상해요',
#  '고추잡채을 새콤해요',
#  '고추잡채을 새콤해요',
#  '고추잡채을 싱싱해요',
#  '고추잡채을 싸요',
#  '고추잡채을 싸요',
#  '고추잡채을 씻어요',
#  '고추잡채을 씻어요',
#  '고추잡채을 익어요',
#  '고추잡채을 익어요',
#  '고추잡채을 잘라주세요',
#  '고추잡채을 잘라주세요',
#  '과자을 깎아요',
#  '과자을 깎아요',
#  '과자을 따요',
#  '과자을 따요',
#  '과자을 사요',
#  '과자을 사요',
#  '과자을 상해요',
#  '과자을 상해요',
#  '과자을 새콤해요',
#  '과자을 새콤해요',
#  '과자을 싱싱해요',
#  '과자을 싸요',
#  '과자을 싸요',
#  '과자을 씻어요',
#  '과자을 씻어요',
#  '과자을 익어요',
#  '과자을 익어요',
#  '과자을 잘라주세요',
#  '과자을 잘라주세요',
#  '과자을 깎아요',
#  '과자을 깎아요',
#  '과자을 따요',
#  '과자을 따요',
#  '과자을 사요',
#  '과자을 사요',
#  '과자을 상해요',
#  '과자을 상해요',
#  '과자을 새콤해요',
#  '과자을 새콤해요',
# ...

# %%
pip install konlpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from konlpy.tag import Okt

# %%
okt = Okt()

# %%
import platform
print(platform.architecture())
# Out:
# ('64bit', 'WindowsPE')

# %%
import os

print('JAVA_HOME' in os.environ)
# Out:
# False

# %%
os.environ['JAVA_HOME'] = r"C:\Program Files\Java\jdk-20"

# %%
import os

print('JAVA_HOME' in os.environ)
# Out:
# True

# %%
text = "네스퀵을 싱싱해요"
print(okt.morphs(text))
print(okt.morphs(text, stem=True)) # 형태소 단위로 나눈 후 어간을 추출
# Out:
# ['네스퀵', '을', '싱싱해요']
# ['네스퀵', '을', '싱싱하다']

# %%
print(okt.nouns(text))
print(okt.phrases(text))
# Out:
# []
# ['TV']

# %%
okt.pos(text)[-1][-1]
# Out:
# 'Adjective'

# %%
print(okt.pos(text))
print(okt.pos(text, join=True)) # 형태소와 품사를 붙여서 리스트화
# Out:
# [('TV', 'Alpha'), ('보고싶어요', 'Verb')]
# ['TV/Alpha', '보고싶어요/Verb']

# %% [markdown]
# - 문장 품사도 konlpy 를 이용해서 나눔
# -

# %%
# Out:
#             text                                              image
# 0        TV보고싶어요  http://220.69.171.28:8080/Symbol/Symbol/n1_gi_...
# 1      가방(실내화가방)  http://220.69.171.28:8080/Symbol/Symbol/n1_gi_...
# 2             간식  http://220.69.171.28:8080/Symbol/Symbol/n1_gi_...
# 3             간식  http://220.69.171.28:8080/Symbol/Symbol/n1_gi_...
# 4          감사합니다  http://220.69.171.28:8080/Symbol/Symbol/n1_gi_...
# ...          ...                                                ...
# 10354  휠체어가 고장나다  http://220.69.171.28:8080/Symbol/Symbol/keo_my...
# 10355      휠체어책상  http://220.69.171.28:8080/Symbol/Symbol/scom/h...
# 10356        휴대폰  http://220.69.171.28:8080/Symbol/Symbol/scom/h...
# 10357       흐뭇하다  http://220.69.171.28:8080/Symbol/Symbol/scom/h...
# 10358         흡연  http://220.69.171.28:8080/Symbol/Symbol/keo_my...
#
# [10359 rows x 2 columns]

# %%
li_temp = []

for i in range(df.shape[0]):
    text = df.iloc[i,0]
    temp=okt.pos(text)[-1][-1]
    li_temp.append(temp)

# %%
df
# Out:
#             text                                              image
# 0        TV보고싶어요  http://220.69.171.28:8080/Symbol/Symbol/n1_gi_...
# 1      가방(실내화가방)  http://220.69.171.28:8080/Symbol/Symbol/n1_gi_...
# 2             간식  http://220.69.171.28:8080/Symbol/Symbol/n1_gi_...
# 3             간식  http://220.69.171.28:8080/Symbol/Symbol/n1_gi_...
# 4          감사합니다  http://220.69.171.28:8080/Symbol/Symbol/n1_gi_...
# ...          ...                                                ...
# 10354  휠체어가 고장나다  http://220.69.171.28:8080/Symbol/Symbol/keo_my...
# 10355      휠체어책상  http://220.69.171.28:8080/Symbol/Symbol/scom/h...
# 10356        휴대폰  http://220.69.171.28:8080/Symbol/Symbol/scom/h...
# 10357       흐뭇하다  http://220.69.171.28:8080/Symbol/Symbol/scom/h...
# 10358         흡연  http://220.69.171.28:8080/Symbol/Symbol/keo_my...
#
# [10359 rows x 2 columns]

# %%
text = '나는_반이에요'
okt.pos(text)
# Out:
# [('나', 'Noun'),
#  ('는', 'Josa'),
#  ('_', 'Punctuation'),
#  ('반', 'Noun'),
#  ('이에요', 'Josa')]

# %%
df.iloc[8,0]
# Out:
# '고마워요'

# %%
li_temp[17]
# Out:
# 'Josa'

# %%
li_temp.count('Josa')
# Out:
# 504

# %%
li_temp.count('Adjective')
# Out:
# 695

# %%
li_temp
# Out:
# ['Verb',
#  'Punctuation',
#  'Noun',
#  'Noun',
#  'Verb',
#  'Verb',
#  'Verb',
#  'Verb',
#  'Adjective',
#  'Verb',
#  'Verb',
#  'Verb',
#  'Verb',
#  'Verb',
#  'Noun',
#  'Noun',
#  'Verb',
#  'Josa',
#  'Josa',
#  'Josa',
#  'Josa',
#  'Josa',
#  'Josa',
#  'Josa',
#  'Josa',
#  'Josa',
#  'Josa',
#  'Adjective',
#  'Noun',
#  'Noun',
#  'Noun',
#  'Josa',
#  'Josa',
#  'Adjective',
#  'Josa',
#  'Josa',
#  'Josa',
#  'Verb',
#  'Noun',
#  'Noun',
#  'Noun',
#  'Josa',
#  'Josa',
#  'Verb',
#  'Verb',
#  'Josa',
#  'Adjective',
#  'Adjective',
#  'Adjective',
#  'Verb',
#  'Verb',
#  'Punctuation',
#  'Verb',
#  'Josa',
#  'Verb',
#  'Verb',
#  'Verb',
#  'Verb',
#  'Josa',
#  'Josa',
#  'Adjective',
#  'Adjective',
#  'Adjective',
#  'Adjective',
#  'Verb',
#  'Verb',
#  'Verb',
#  'Adjective',
#  'Adjective',
#  'Josa',
#  'Noun',
#  'Adjective',
#  'Adjective',
#  'Verb',
#  'Verb',
#  'Verb',
#  'Verb',
#  'Verb',
#  'Noun',
#  'Noun',
#  'Noun',
#  'Noun',
#  'Noun',
# ...

# %%
df_new = df.copy()

# %%
df_new['문장품사'] = li_temp
df_new['보기편하게'] = df_new['text']

# %%
df_new.to_csv('df_new.csv',encoding='utf-8-sig',index=False)

# %%
df_new
# Out:
#             text                                              image  \
# 0        TV보고싶어요  http://220.69.171.28:8080/Symbol/Symbol/n1_gi_...
# 1      가방(실내화가방)  http://220.69.171.28:8080/Symbol/Symbol/n1_gi_...
# 2             간식  http://220.69.171.28:8080/Symbol/Symbol/n1_gi_...
# 3             간식  http://220.69.171.28:8080/Symbol/Symbol/n1_gi_...
# 4          감사합니다  http://220.69.171.28:8080/Symbol/Symbol/n1_gi_...
# ...          ...                                                ...
# 10354  휠체어가 고장나다  http://220.69.171.28:8080/Symbol/Symbol/keo_my...
# 10355      휠체어책상  http://220.69.171.28:8080/Symbol/Symbol/scom/h...
# 10356        휴대폰  http://220.69.171.28:8080/Symbol/Symbol/scom/h...
# 10357       흐뭇하다  http://220.69.171.28:8080/Symbol/Symbol/scom/h...
# 10358         흡연  http://220.69.171.28:8080/Symbol/Symbol/keo_my...
#
#               문장품사
# 0             Verb
# 1      Punctuation
# 2             Noun
# 3             Noun
# 4             Verb
# ...            ...
# ...

# %% [markdown]
# - 형용사면 ~이 ~가 ~에요
# - 동사면 ~

# %%
a = df_new[df_new['문장품사'] == 'Noun']
b = df_new[df_new['문장품사'] == 'Verb']

ans = []

for i in range(a.shape[0]):

    for j in range(b.shape[0]):
        ans.append(a.iloc[i,0] + b.iloc[j,0])

# %%
len(ans) #천만개의 문장을 20분걸림
# Out:
# 13966043

# %% [markdown]
# 시도 1 : 그냥 만들기
# 시도 2 : 장소, 시간등의 카테고리도 설정학
# 시도 3 : 같은 카테고리의 언어끼리만 문장만들기(어짜피 다른 카테고리와 연관될 확률이 적어서)
#
#
# ---
#
# 추가로 해당 동사 토큰이 몇개의 단어가 필요한지 적기
# ex) 먹고 싶어요는 먹고싶은 대상 + 싶어요 총 2개
#
#
# 먼저 명사를 분리해서 거기서 내가 새로적고 다시 분리된것을 붙히기??

# %%
#오늘 - 음식
#금요일 - 2개
#토요일 - 2개
#일요일 - 2개

# %%
df_food = pd.read_csv('df_food.csv')

# %%
df_food['필요토큰'] = '0'

# %%
for i in range(df_food.shape[0]):
    text = df_food.iloc[i,2]
    if text =='0':
        df_food.iloc[i,2] = '동사'

# %%
df_food['카테고리_주제'].value_counts()
# Out:
# 카테고리_주제
# 명사    766
# 동사    301
# 부사      8
# Name: count, dtype: int64

# %%
df_food['필요토큰'] = '0'

# %%
df_food.to_csv('df_food2.csv',encoding='utf-8-sig',index=False)

# %%
df_food = pd.read_csv('df_food2.csv')

# %%
df_food
# Out:
#         text                                              image 카테고리_주제  \
# 0     간장에찍어요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      동사
# 1        갈비탕  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사
# 2       고추잡채  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사
# 3     고추장넣어요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      동사
# 4     고추장주세요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      동사
# ...      ...                                                ...     ...
# 1070    프라이팬  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사
# 1071    프라이팬  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사
# 1072     하나더  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      부사
# 1073     하나더  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      부사
# 1074     정말요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      동사
#
#      카테고리_품사  필요토큰 목적어
# 0          0     1   을
# 1          0     0   0
# 2          0     0   0
# ...

# %%
df_food['목적어'].value_counts()
# Out:
# 목적어
# 0    878
# 을    119
# 이     63
# 에      9
# 병      2
# 은      2
# 정      1
# 의      1
# Name: count, dtype: int64

# %%
list = ['ㅏ','ㅐ','ㅑ','ㅒ','ㅓ','ㅔ','ㅕ','ㅖ','ㅗ','ㅘ','ㅙ','ㅚ','ㅛ','ㅜ','ㅝ','ㅞ','ㅟ','ㅠ','ㅡ','ㅢ','ㅣ']

def is_n(text):
    if extract_consonant(text) in list:
        return '가'
    else:
        return '이'

# %%
df_food.query('(카테고리_주제 == "명사") and (카테고리_품사 == "0")')
# Out:
#       text                                              image 카테고리_주제 카테고리_품사  \
# 1      갈비탕  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사       0
# 2     고추잡채  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사       0
# 5       과자  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사       0
# 6       과자  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사       0
# 8        국  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사       0
# ...    ...                                                ...     ...     ...
# 986     피자  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사       0
# 987     피자  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사       0
# 990     피클  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사       0
# 997   해물잡탕  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사       0
# 1028    몇개  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      명사       0
#
#       필요토큰 목적어
# 1        0   0
# ...

# %%
df_food_v = df_food[df_food['카테고리_주제'] =='동사']

# %%
df_food_v
# Out:
#         text                                              image 카테고리_주제  \
# 0     간장에찍어요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      동사
# 3     고추장넣어요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      동사
# 4     고추장주세요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      동사
# 7        구워요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      동사
# 10     김치볶음밥  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      동사
# ...      ...                                                ...     ...
# 1043    싸주세요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      동사
# 1044    싸주세요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      동사
# 1053  정리해주세요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      동사
# 1058  짝이안맞아요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      동사
# 1074     정말요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      동사
#
#      카테고리_품사  필요토큰 목적어
# 0          0     1   을
# 3          0     0   0
# 4          0     0   0
# ...

# %%
df_food_v.reset_index(drop = True,inplace=True)

# %%
df_food_v
# Out:
#        text                                              image 카테고리_주제  \
# 0    간장에찍어요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      동사
# 1    고추장넣어요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      동사
# 2    고추장주세요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      동사
# 3       구워요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      동사
# 4     김치볶음밥  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      동사
# ..      ...                                                ...     ...
# 291    싸주세요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      동사
# 292    싸주세요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      동사
# 293  정리해주세요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      동사
# 294  짝이안맞아요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      동사
# 295     정말요  http://220.69.171.28:8080/Symbol/Symbol/n2_eum...      동사
#
#     카테고리_품사  필요토큰 목적어
# 0         0     1   을
# 1         0     0   0
# 2         0     0   0
# ...

# %%
df_food_n = df_food.query('(카테고리_주제 == "명사") and (카테고리_품사 == "0")')
df_food_li = df_food_n['text'].to_list()


sen = []


#도구가 아닌 음식만 가져옴


for i in df_food_li:
    for j in range(df_food_v.shape[0]):
        if df_food_v.iloc[j,5] != '0':
        
            text = df_food_v
            sen.append(i + df_food_v.iloc[j,5] + " " + df_food_v.iloc[j,0])

# %%
len(sen)
# Out:
# 124405

# %%
sen
# Out:
# ['갈비탕을 간장에찍어요',
#  '갈비탕을 구워요',
#  '갈비탕을 까주세요',
#  '갈비탕을 끓여요',
#  '갈비탕이 느끼해요',
#  '갈비탕을 다먹었어요',
#  '갈비탕병 다먹었어요',
#  '갈비탕이 딱딱해요',
#  '갈비탕을 떠주세요',
#  '갈비탕이 뜨거워요',
#  '갈비탕이 뜨거워요',
#  '갈비탕이 뜨거워요',
#  '갈비탕이 뜨거워요',
#  '갈비탕을 마시고싶어요',
#  '갈비탕이 맛없어요',
#  '갈비탕이 맛있어요',
#  '갈비탕이 맛있어요',
#  '갈비탕이 매워요',
#  '갈비탕이 매워요',
#  '갈비탕이 매워요',
#  '갈비탕을 못먹어요',
#  '갈비탕병 못먹어요',
#  '갈비탕정 못먹어요',
#  '갈비탕이 바삭해요',
#  '갈비탕을 발라요',
#  '갈비탕을 배달해주세요',
#  '갈비탕이 배불러요',
#  '갈비탕이 별로예요',
#  '갈비탕이 부족해요',
#  '갈비탕이 불어요',
#  '갈비탕을 삶아주세요',
#  '갈비탕을 선물받았어요',
#  '갈비탕을 선물해요',
#  '갈비탕을 시켜주세요',
#  '갈비탕을 시켜주세요',
#  '갈비탕을 식혀요',
#  '갈비탕을 식혀주세요',
#  '갈비탕이 싱거워요',
#  '갈비탕이 싱거워요',
#  '갈비탕에 알레르기있어요',
#  '갈비탕에 알레르기있어요',
#  '갈비탕은 어때요',
#  '갈비탕이 질겨요',
#  '갈비탕이 쫄깃해요',
#  '갈비탕이 차가워요',
#  '갈비탕이 차가워요',
#  '갈비탕을 튀겨요',
#  '갈비탕을 퍼주세요',
#  '갈비탕을 포장해요',
#  '갈비탕을 갈아주세요',
#  '갈비탕을 갈아주세요',
#  '갈비탕을 끓여주세요',
#  '갈비탕을 더먹고싶어요',
#  '갈비탕을 더먹고싶어요',
#  '갈비탕을 따주세요',
#  '갈비탕이 떫어요',
#  '갈비탕이 떫어요',
#  '갈비탕을 마셔요',
#  '갈비탕을 마셔요',
#  '갈비탕을 마실래요',
#  '갈비탕을 만들어요',
# ...

# %%
import pickle


with open("list_food.pkl","wb") as f:
    pickle.dump(sen, f)

# %%
import pickle


with open("all_x.pkl","wb") as f:
    pickle.dump(ans, f)

# %%
import pickle

with open("list_ex.pkl","rb") as f:
    list_ex_load = pickle.load(f)

# %% [markdown]
# # 교육관련 데이터 만들기

# %%
url = "http://symbol.ksaac.or.kr/searchsymbols/searchbycategory?cago=4"

li_school_text = get_text(url)
li_school_image = get_image(url)

df_school = make_df(li_school_text,li_school_image)

df_school['카테고리_주제'] = '학교'
df_school['카테고리_품사'] = '0'

# %%
from tqdm import tqdm

noun = list(map(lambda x : is_noun(x),df_school['text'].to_list()))

df_school['카테고리_품사'] = noun

# %%
df_school
# Out:
#               text                                              image 카테고리_주제  \
# 0             공부시간  http://220.69.171.28:8080/Symbol/Symbol/n3_hag...      학교
# 1              과학실  http://220.69.171.28:8080/Symbol/Symbol/n3_hag...      학교
# 2         교과서를펴주세요  http://220.69.171.28:8080/Symbol/Symbol/n3_hag...      학교
# 3               교육  http://220.69.171.28:8080/Symbol/Symbol/n3_hag...      학교
# 4           나가서놀래요  http://220.69.171.28:8080/Symbol/Symbol/n3_hag...      학교
# ..             ...                                                ...     ...
# 818             압정  http://220.69.171.28:8080/Symbol/Symbol/n3_hag...      학교
# 819  체육복으로 갈아입어주세요  http://220.69.171.28:8080/Symbol/Symbol/n3_hag...      학교
# 820  체육복으로 갈아입어주세요  http://220.69.171.28:8080/Symbol/Symbol/n3_hag...      학교
# 821         화재 경보기  http://220.69.171.28:8080/Symbol/Symbol/n3_hag...      학교
# 822          화재경보기  http://220.69.171.28:8080/Symbol/Symbol/n3_hag...      학교
#
#     카테고리_품사
# 0         0
# ...

# %%
df_school.to_csv('df_school.csv',encoding='utf-8-sig',index= False)

# %%
df_school = pd.read_csv('df_school.csv')

# %%
df_school['필요토큰'] = '0'
df_school['필요성분'] = '0'

# %%
df_school.to_csv('df_school2.csv',encoding='utf-8-sig',index= False)
